# %%
Incidents = Incident.objects.filter(what__contains='coal')

for i in Incidents:
    print "\n\n{}\t{}\n{}\n".format(i.id, i.address, i.what,)
# Out:
# 300	2393-2429 Flag Marsh Road, Mount Airy, MD 21771, USA
# <p>I was riding west bound on Flag Marsh Rd, when the driver of a red ford F350 4x4 pickup truck, Maryland plate 360 38FT rolled coal on me and my riding partner. &nbsp;We were part of a larger group of riders that were strung out on the route, and riders in the other groups reported that this pickup truck also "rolled coal" on them as well.</p><p>This occurred at 6:46 PM on 7/30/2015. &nbsp; The vehicle is registered to an address in Mt. Airy, MD and was driven by a young white woman.</p><p>Carroll County police were contacted and did talk with the young woman driving the truck at the time, but no other action was taken.</p>
#
#     <p>The incident was captured on a <a href="https://cycliq.com/product/fly6" target="_blank">Fly6 video camera</a>. Watch it below or on <a href="https://youtu.be/h8k8bhGrXIo" target="_blank">You Tube</a>.</p>
#     <p>
#
#       <div class="responsive-embed-16by9-iframe-youtube">
# ...

# %%
Incidents = Incident.objects.filter(license_certain__contains='33')

for i in Incidents:
    print "\n{}\t{}\t{}\n".format(i.id, i.address, i.license_certain,)
    
Incidents = Incident.objects.filter(license_uncertain__contains='33')

for i in Incidents:
    print "\n{}\t{}\t{}\n".format(i.id, i.address, i.license_uncertain,)
# Out:
# 349	20100 Engelmann Ln, Manor, TX 78653, USA	BD1 3384 (TX)
#
#
# 288	6224-6258 El Camino Real, Carlsbad, CA 92009, USA	7CPS733
#
#
# 243	766-774 New York 22, White Plains, NY 10603, USA	NY plate FLM 3345
#
#
# 178	463 Stage Road, Little Egg Harbor Township, NJ 08087, USA	SYG 33S (New Jersey)
#
#
# 207	12219-12419 Fitzhugh Road, Austin, TX 78736, USA	TX: CTB 4733
#
#
# 125	4801-4805 California 84, Sunol, CA 94586, USA	CA: 6JCA330
#
#
# 93	4100-4298 Carey Avenue, Cheyenne, WY 82001, USA	WY: 2-3373B

# %%
Incidents = Incident.objects.filter(address__contains='CA')

for i in Incidents:
    print "\n{}\t{}\t{}\t{}\n".format(i.id, i.address, i.license_certain, i.license_uncertain,)
# Out:
# 492	276 Grand Ave, Oakland, CA 94610, USA	California 6L0C505
#
#
# 489	13786-14998 Uvas Rd, Morgan Hill, CA 95037, USA
#
#
# 480	3150-3768 Buena Vista Rd, Ione, CA 95640, USA		CA: 49153J1
#
#
# 494	3755 Shoreline Hwy, Stinson Beach, CA 94970, USA	CA 6T02341
#
#
# 477	18112-18346 Uvas Rd, Morgan Hill, CA 95037, USA	6RHF711
#
#
# 472	11800-12098 Ted Williams Pkwy, San Diego, CA 92128, USA	CA 7ETN370
#
#
# 451	2917-3213 Tavern Rd, Alpine, CA 91901, USA	California	EAGLDY
#
#
# 435	17530 County Hwy S9, Encinitas, CA 92024, USA	6VJC199
#
#
# 426	2733 Monroe St, Carlsbad, CA 92008, USA
#
#
# 427	2945-3143 Mission Ave, Oceanside, CA 92054, USA	California 75197D1
#
#
# 422	918 Hiller St, Belmont, CA 94002, USA		CA: 8439211
#
#
# 421	4200 Buena Vista Rd, Ione, CA 95640, USA
#
#
# 418	8710-8796 CA-35, California, USA		CA 900BV (handicap plates)
#
#
# 416	340-706 Paloma Rd, Valley Springs, CA 95252, USA		CA commercial: possibly ends with 1471
#
#
# ...

# %%
Incidents = Incident.objects.filter(vehicle_description__contains='truck')

for i in Incidents:
    print "\n{}\t{}\t{}\t{}\n{}\n".format(i.id, i.address, i.license_certain, i.license_uncertain, i.vehicle_description)
# Out:
# 489	13786-14998 Uvas Rd, Morgan Hill, CA 95037, USA
# Construction water truck, white with blue stripes with the lettering "Corral" on the door
#
#
# 480	3150-3768 Buena Vista Rd, Ione, CA 95640, USA		CA: 49153J1
# Red Dodge Ram 3500 Pickup truck towing an empty trailer
#
#
# 478	1600 E 17th Ave, Denver, CO 80218, USA	Colorado 870-LVG
# Red Toyota Tacoma pickup truck with bed topper
#
#
# 494	3755 Shoreline Hwy, Stinson Beach, CA 94970, USA	CA 6T02341
# White pick up truck with small horitonzal black panel and silver hubs
#
#
# 473	1610 Creek Rd, Dripping Springs, TX 78620, USA
# Black pickup truck
#
#
# 462	7629 State Rd 1119, Holly Springs, NC 27540, USA	EB-1329	North Carolina
# White Chevy Silverado pickup truck, recent model year.
#
#
# 430	6316-6320 Baseline Rd, Boulder, CO 80303, USA	unknown	unknown
# Green moving truck with TAYLOR MOVING & STORAGE decals
#
#
# 416	340-706 Paloma Rd, Valley Springs, CA 95252, USA		CA commercial: possibly ends with 1471
# ...
